# %% [markdown]
# # Searching for patterns in RDKit lists

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Draw import MolDrawing, DrawingOptions

# %%
import cPickle as pickle

# %%
smiles_dict = pickle.load(open('test_15a_200n_hal_chembl19.pkl','rb'))

# %%
mols = [Chem.MolFromSmiles(smi) for smi in smiles_dict.values()]

# %%
Chem.Draw.MolsToGridImage(mols,molsPerRow=4)
# Out:
# <Image.Image image mode=RGBA size=800x5800 at 0x1065B7C68>
